# %%
import requests
import json
base_url = 'https://api.fitbit.com'
user_id = '5FR3J5'
access_token='eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIyM1BRREgiLCJzdWIiOiI1RlIzSjUiLCJpc3MiOiJGaXRiaXQiLCJ0eXAiOiJhY2Nlc3NfdG9rZW4iLCJzY29wZXMiOiJyc29jIHJzZXQgcm94eSBybnV0IHJwcm8gcnNsZSByYWN0IHJsb2MgcnJlcyByd2VpIHJociBydGVtIiwiZXhwIjoxNzU1NTQ4MjMzLCJpYXQiOjE3MjQwMTIyMzN9.uH7tJ-m78eftEz0nMJBsCqKc7IVQMhk2GFSX5wgQQhk'

# %%
url = "https://api.fitbit.com/1.2/user/{}/sleep/date/2021-06-01/2021-08-01.json".format(user_id)
response = requests.get(url=url, headers=headers)

# %%
url = "https://api.fitbit.com//1/user/{}/profile.json".format(user_id)
response = requests.get(url=url, headers=headers)
print(response.text)
# Out:
# {"user":{"age":47,"ambassador":false,"autoStrideEnabled":true,"avatar":"https://asset-service.fitbit.com/b4767cb0-06a4-11ec-8e8a-fd7890293508_profile_100_square.jpg","avatar150":"https://asset-service.fitbit.com/b4767cb0-06a4-11ec-8e8a-fd7890293508_profile_150_square.jpg","avatar640":"https://asset-service.fitbit.com/b4767cb0-06a4-11ec-8e8a-fd7890293508_profile_640_square.jpg","averageDailySteps":0,"challengesBeta":true,"clockTimeDisplayFormat":"24hour","corporate":false,"corporateAdmin":false,"country":"FI","dateOfBirth":"1976-08-31","displayName":"Ravi B.","displayNameSetting":"name","distanceUnit":"METRIC","encodedId":"5FR3J5","features":{"exerciseGoal":true},"firstName":"Ravi","foodsLocale":"en_IN","fullName":"Ravi Basa","gender":"MALE","glucoseUnit":"en_US","height":176.0,"heightUnit":"METRIC","isBugReportEnabled":false,"isChild":false,"isCoach":false,"languageLocale":"en_FI","lastName":"Basa","legalTermsAcceptRequired":true,"locale":"en_FI","memberSince":"2017-02-03","mfaEnable
# ...

# %%
url = "https://api.fitbit.com/1.2/user/{}/sleep/date/2021-06-01/2021-08-01.json".format(user_id)
response = requests.get(url=url, headers=headers)
print(response.text)
# Out:
# {"sleep":[{"dateOfSleep":"2021-08-01","duration":13980000,"efficiency":91,"endTime":"2021-08-01T10:23:30.000","infoCode":0,"isMainSleep":true,"levels":{"data":[{"dateTime":"2021-08-01T06:30:30.000","level":"light","seconds":240},{"dateTime":"2021-08-01T06:34:30.000","level":"wake","seconds":630},{"dateTime":"2021-08-01T06:45:00.000","level":"light","seconds":3330},{"dateTime":"2021-08-01T07:40:30.000","level":"deep","seconds":1230},{"dateTime":"2021-08-01T08:01:00.000","level":"light","seconds":180},{"dateTime":"2021-08-01T08:04:00.000","level":"rem","seconds":270},{"dateTime":"2021-08-01T08:08:30.000","level":"light","seconds":1230},{"dateTime":"2021-08-01T08:29:00.000","level":"rem","seconds":1140},{"dateTime":"2021-08-01T08:48:00.000","level":"light","seconds":420},{"dateTime":"2021-08-01T08:55:00.000","level":"wake","seconds":330},{"dateTime":"2021-08-01T09:00:30.000","level":"light","seconds":720},{"dateTime":"2021-08-01T09:12:30.000","level":"deep","seconds":1200},{"dateTime":"
# ...
